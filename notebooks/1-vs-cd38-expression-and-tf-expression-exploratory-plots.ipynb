# %%
from helpers import getGOI, getProcessedData, exploratoryPlots
#a change in branch cd46

# %%
goi_id = getGOI()

goi_pat_log, X_log, y_log, X_log_train, X_log_test, y_log_train, y_log_test = getProcessedData(goi_id)

# %%
exploratoryPlots(y_log_train.append(y_log_test), goi_pat_log)
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f55c1c4c82af> in <module>
# ----> 1 exploratoryPlots(y_log_train.append(y_log_test), goi_pat_log)
#
# ~/CD38_Predictor/notebooks/helpers.py in exploratoryPlots(y, X)
#     162     sns.distplot(y)
#     163     plt.title("CD46 expression")
# --> 164     plt.savefig('../summary/figures/CD46_expression_distribution_patients.png')
#     165     plt.figure(figsize=(19,25))
#     166     sns.barplot(data=X, orient = 'h')
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# ...
