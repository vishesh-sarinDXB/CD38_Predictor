# %%
from helpers import *
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold, RandomizedSearchCV
import xgboost as xgb
import numpy as np
from scipy.stats import uniform, randint
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
goi_id = getGOI()

X_log, y_log, X_log_train, X_log_test, y_log_train, y_log_test = getProcessedData(goi_id)
# Out:
# /home/swagmaster/CD38_Predictor/helpers.py:171: RuntimeWarning: divide by zero encountered in log2
#   goi_pat_log = np.log2(goi_pat)

# %%
xgb_model, params = getModelAndBestParams(X_log_train, y_log_train)

# %%
mae = getMAEandPlots(xgb_model, X_log_train, X_log_test, y_log_train, y_log_test)

# %%
buildNewModel(params)
# Out:
# XGBRegressor(base_score=None, booster=None,
#              colsample_bylevel=0.6150926341207776,
#              colsample_bynode=0.7495966899423762,
#              colsample_bytree=0.7860020996045916, gamma=0.768554014306309,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.04360377175443375, max_delta_step=None,
#              max_depth=5, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=191, n_jobs=-1,
#              num_parallel_tree=None, random_state=42, reg_alpha=None,
#              reg_lambda=None, scale_pos_weight=None,
#              subsample=0.7349722569954715, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
params
# Out:
# {'colsample_bylevel': 0.6150926341207776,
#  'colsample_bynode': 0.7495966899423762,
#  'colsample_bytree': 0.7860020996045916,
#  'gamma': 0.768554014306309,
#  'learning_rate': 0.04360377175443375,
#  'max_depth': 5,
#  'n_estimators': 191,
#  'subsample': 0.7349722569954715}

# %%
params
# Out:
# {'colsample_bylevel': 0.6150926341207776,
#  'colsample_bynode': 0.7495966899423762,
#  'colsample_bytree': 0.7860020996045916,
#  'gamma': 0.768554014306309,
#  'learning_rate': 0.04360377175443375,
#  'max_depth': 5,
#  'n_estimators': 191,
#  'subsample': 0.7349722569954715}
