# %%
from helpers import *
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold, RandomizedSearchCV
import xgboost as xgb
import numpy as np
from scipy.stats import uniform, randint
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
import re
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/swagmaster/anaconda3/envs/wiita/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/swagmaster/anaconda3/envs/wiita/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
goi_id = getGOI()

X_log, y_log, X_log_train, X_log_test, y_log_train, y_log_test = getProcessedData(goi_id)
# Out:
# /home/swagmaster/CD38_Predictor/helpers.py:206: RuntimeWarning: divide by zero encountered in log2
#   goi_pat_log = np.log2(goi_pat)

# %%
xgb, params = getModelAndBestParams(X_log_train, y_log_train, 10)

# %%
mae = getMAEandPlots(xgb, X_log_train, X_log_test, y_log_train, y_log_test)

# %%
X_corr, X_train_corr, X_test_corr = getCorrAndHighCorrFeatures(X_log, y_log, X_log_train, X_log_test)

# %%
xgb_corr = buildNewModelAndFit(params, X_train_corr, y_log_train)

# %%
mae_corr = getMAEandPlots(xgb_corr, X_train_corr, X_test_corr, y_log_train, y_log_test, 'Top 20 Correlated Features')

# %%
perm_xgb, perm_regr, X_RF_train, X_RF_test, X_XGB_train, X_XGB_test = permImportance(params, X_log_train, X_log_test, y_log_train, y_log_test)

# %%
perm_xgb
# Out:
#     feature    weight       std
# 0      XBP1  0.070260  0.014859
# 1    POU2F1  0.047878  0.010832
# 2      ATF1  0.034236  0.013837
# 3      BCL3  0.029377  0.008425
# 4      RBPJ  0.029343  0.007205
# ..      ...       ...       ...
# 104    EZH2 -0.004627  0.004976
# 105    KLF5 -0.004707  0.001274
# 106   TBX21 -0.005373  0.001532
# 107    NFIC -0.006055  0.002191
# 108    RELA -0.006202  0.003395
#
# [109 rows x 3 columns]

# %%
perm_regr
# Out:
#     feature    weight       std
# 0      ATF1  0.070442  0.012942
# 1      XBP1  0.069379  0.016293
# 2      RBPJ  0.049354  0.011625
# 3     STAT1  0.031914  0.013431
# 4       AHR  0.022366  0.002972
# ..      ...       ...       ...
# 104    EZH2 -0.001694  0.001163
# 105     MAZ -0.002036  0.001228
# 106    NFIC -0.002607  0.001105
# 107    NFYB -0.002631  0.002488
# 108    JUND -0.002986  0.001936
#
# [109 rows x 3 columns]

# %%
X_RF_train.head()
# Out:
# GENE_NAMES           ATF1       XBP1       RBPJ      STAT1       AHR  \
# MMRF_2829_1_BM   9.702173  14.817633  13.035486  15.090361  8.405141
# MMRF_1766_1_BM  10.741467  17.790145  12.924070  14.103206  6.599913
# MMRF_2098_1_BM   9.445015  16.911825  11.131214  13.411908  7.118941
# MMRF_2168_1_BM   9.868823  16.110667  11.997532  13.492354  5.209453
# MMRF_2314_1_BM  11.144658  16.706955  12.766943  14.766995  5.977280
#
# GENE_NAMES          GCFC2     POU2F1      CREB1        FOS       BCL3  \
# MMRF_2829_1_BM  10.865733  12.459432  11.660887   9.505812  10.406205
# MMRF_1766_1_BM   9.121534  11.693051  11.839597  14.722914   9.357552
# MMRF_2098_1_BM   8.499846  10.559377  10.124121  16.865165  10.851749
# MMRF_2168_1_BM   9.149747  11.736402  11.164278  17.274642   9.477758
# MMRF_2314_1_BM  10.586840  11.734286  11.930737  16.839979  10.246741
#
# GENE_NAMES           SPI1       IRF2       ESR1        SRF       IRF1  \
# MMRF_2829_1_BM  11.535275   9.392317   9.556506  13.310187  13.602467
# MMRF_1766_1_BM  10.365229  13.134747  10.178665  12.246147  13.902752
# MMRF_2098_1_BM   9.763212  10.841564   9.764872  12.562719  13.029805
# MMRF_2168_1_BM  10.850968  11.454813  13.387210  11.727920  11.412570
# MMRF_2314_1_BM  10.715962  12.254733   9.912889  12.392317  14.013497
#
# GENE_NAMES            EED    BHLHE40      RCOR1       JUNB      NR3C1
# MMRF_2829_1_BM  11.698271  10.482808   8.396605  12.937190  13.628673
# MMRF_1766_1_BM  10.393390   5.247928  10.819381  13.585784  13.396471
# MMRF_2098_1_BM   9.505812   9.164907   8.558421  14.863412  12.386401
# MMRF_2168_1_BM  10.368506  10.264443   9.677720  14.931153  12.178042
# MMRF_2314_1_BM  10.408330   5.930737  10.783817  13.922770  12.891214

# %%
X_RF_test.head()
# Out:
# GENE_NAMES           ATF1       XBP1       RBPJ      STAT1        AHR  \
# MMRF_1744_1_BM  10.425216  17.135529  11.820578  14.158925   8.816984
# MMRF_2437_1_BM  10.124121  16.394144  11.590587  14.448891   8.839204
# MMRF_1713_1_BM  10.092757  17.197927  11.845882  13.931661   7.228819
# MMRF_2813_1_BM   9.214319  14.816184  11.911392  13.053247   7.714246
# MMRF_2822_1_BM   8.748193  13.732697  12.373137  11.288866  10.808160
#
# GENE_NAMES         GCFC2     POU2F1      CREB1        FOS       BCL3  \
# MMRF_1744_1_BM  9.467606  10.621136  10.782179  16.811876   8.823367
# MMRF_2437_1_BM  9.455327  10.501837  10.825754  16.026372   9.921841
# MMRF_1713_1_BM  9.601771  11.068778  11.224002  17.156221   9.370687
# MMRF_2813_1_BM  9.688250  12.439831  11.887601  15.795203  12.851554
# MMRF_2822_1_BM  7.876517  12.179287  11.532843  14.208006  12.730682
#
# GENE_NAMES           SPI1       IRF2       ESR1        SRF       IRF1  \
# MMRF_1744_1_BM   9.712527  11.708653   9.111136  10.875749  12.933506
# MMRF_2437_1_BM   9.294621  11.348728  10.623881  10.632995  12.001760
# MMRF_1713_1_BM  10.425216  12.282509   9.084808  10.992938  12.422590
# MMRF_2813_1_BM  11.786270  10.363040  10.681238  12.844706  13.812077
# MMRF_2822_1_BM  11.909518   8.717676   9.515700  10.938844  13.934797
#
# GENE_NAMES           EED    BHLHE40      RCOR1       JUNB      NR3C1
# MMRF_1744_1_BM  9.739781   8.483816   9.461479  11.360847  11.670214
# MMRF_2437_1_BM  9.818582  11.237807   9.658211  14.640075  12.568194
# MMRF_1713_1_BM  9.871905   7.159871   9.569856  13.734815  14.023841
# MMRF_2813_1_BM  8.625709   9.839204  10.817783  16.083770  14.097950
# MMRF_2822_1_BM  9.287712  11.118292   9.908393  15.878506  13.171959

# %%
X_XGB_train.head()
# Out:
# GENE_NAMES           XBP1     POU2F1       ATF1       BCL3       RBPJ  \
# MMRF_2829_1_BM  14.817633  12.459432   9.702173  10.406205  13.035486
# MMRF_1766_1_BM  17.790145  11.693051  10.741467   9.357552  12.924070
# MMRF_2098_1_BM  16.911825  10.559377   9.445015  10.851749  11.131214
# MMRF_2168_1_BM  16.110667  11.736402   9.868823   9.477758  11.997532
# MMRF_2314_1_BM  16.706955  11.734286  11.144658  10.246741  12.766943
#
# GENE_NAMES          STAT1       AHR      ETS2      CREB1      GCFC2  \
# MMRF_2829_1_BM  15.090361  8.405141  4.857981  11.660887  10.865733
# MMRF_1766_1_BM  14.103206  6.599913  1.000000  11.839597   9.121534
# MMRF_2098_1_BM  13.411908  7.118941  6.882643  10.124121   8.499846
# MMRF_2168_1_BM  13.492354  5.209453  6.000000  11.164278   9.149747
# MMRF_2314_1_BM  14.766995  5.977280  6.087463  11.930737  10.586840
#
# GENE_NAMES            FOS    BHLHE40       SPI1       ELF1       TP53  \
# MMRF_2829_1_BM   9.505812  10.482808  11.535275  11.938109   9.848623
# MMRF_1766_1_BM  14.722914   5.247928  10.365229  12.928703  12.261213
# MMRF_2098_1_BM  16.865165   9.164907   9.763212  12.047806  10.373953
# MMRF_2168_1_BM  17.274642  10.264443  10.850968  12.772727  11.261507
# MMRF_2314_1_BM  16.839979   5.930737  10.715962  13.272338  12.581201
#
# GENE_NAMES          STAT4       MXI1        AR      BATF     BCL11A
# MMRF_2829_1_BM   7.787903  13.459560  3.000000  1.584963  10.409391
# MMRF_1766_1_BM  10.973697  10.603626  5.044394  5.169925  10.654636
# MMRF_2098_1_BM   9.197217  10.457381  5.044394  4.906891   9.131857
# MMRF_2168_1_BM   9.515700  11.328675  1.000000  4.087463  10.689998
# MMRF_2314_1_BM   8.625709  11.276706  2.584963  6.247928  10.209453

# %%
X_XGB_test.head()
# Out:
# GENE_NAMES           XBP1     POU2F1       ATF1       BCL3       RBPJ  \
# MMRF_1744_1_BM  17.135529  10.621136  10.425216   8.823367  11.820578
# MMRF_2437_1_BM  16.394144  10.501837  10.124121   9.921841  11.590587
# MMRF_1713_1_BM  17.197927  11.068778  10.092757   9.370687  11.845882
# MMRF_2813_1_BM  14.816184  12.439831   9.214319  12.851554  11.911392
# MMRF_2822_1_BM  13.732697  12.179287   8.748193  12.730682  12.373137
#
# GENE_NAMES          STAT1        AHR       ETS2      CREB1     GCFC2  \
# MMRF_1744_1_BM  14.158925   8.816984   6.700440  10.782179  9.467606
# MMRF_2437_1_BM  14.448891   8.839204   6.781360  10.825754  9.455327
# MMRF_1713_1_BM  13.931661   7.228819   5.321928  11.224002  9.601771
# MMRF_2813_1_BM  13.053247   7.714246   6.475733  11.887601  9.688250
# MMRF_2822_1_BM  11.288866  10.808160  10.787086  11.532843  7.876517
#
# GENE_NAMES            FOS    BHLHE40       SPI1       ELF1       TP53  \
# MMRF_1744_1_BM  16.811876   8.483816   9.712527  10.982281  10.292322
# MMRF_2437_1_BM  16.026372  11.237807   9.294621  11.657318   9.939579
# MMRF_1713_1_BM  17.156221   7.159871  10.425216  10.897845  10.816984
# MMRF_2813_1_BM  15.795203   9.839204  11.786270  12.978710  10.581201
# MMRF_2822_1_BM  14.208006  11.118292  11.909518  12.874213   9.204571
#
# GENE_NAMES          STAT4       MXI1        AR      BATF     BCL11A
# MMRF_1744_1_BM  10.080818  11.103943  8.434628  5.584963   9.868823
# MMRF_2437_1_BM  10.668885  10.550747  3.906891  5.357552   9.890264
# MMRF_1713_1_BM  10.712527  10.796851  4.754888  3.321928  10.915132
# MMRF_2813_1_BM  10.292322  11.905763  0.000000  9.350939  10.592457
# MMRF_2822_1_BM  10.639341  12.151968  0.000000  6.357552   8.842350
