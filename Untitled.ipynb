# %%
from helpers import *
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold, RandomizedSearchCV
import xgboost as xgb
import numpy as np
from scipy.stats import uniform, randint
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
goi_id = getGOI()

X_log, y_log, X_log_train, X_log_test, y_log_train, y_log_test = getProcessedData(goi_id)
# Out:
# /home/swagmaster/CD38_Predictor/helpers.py:171: RuntimeWarning: divide by zero encountered in log2
#   goi_pat_log = np.log2(goi_pat)

# %%
xgb, params = getModelAndBestParams(X_log_train, y_log_train)

# %%
mae = getMAEandPlots(xgb, X_log_train, X_log_test, y_log_train, y_log_test)

# %%
X_corr, X_train_corr, X_test_corr = getCorrAndHighCorrFeatures(X_log, y_log, X_log_train, X_log_test)

# %%
xgb_corr = buildNewModel(params)

# %%
# mae_corr = getMAEandPlots(xgb, X_train_corr, X_test_corr, y_log_train, y_log_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ef7af15b6308> in <module>
# ----> 1 mae_corr = getMAEandPlots(xgb, X_train_corr, X_test_corr, y_log_train, y_log_test)
#
# ~/CD38_Predictor/helpers.py in getMAEandPlots(xgb, X_train, X_test, y_train, y_test)
#      41     y_pred_regr = regr.predict(X_test)
#      42     y_pred_regr = pd.Series(y_pred_regr, index = y_test.index)
# ---> 43     y_pred_xgb = xgb.predict(X_test)
#      44     y_pred_xgb = pd.Series(y_pred_xgb, index = y_test.index)
#      45
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     485         """
#     486         self._check_is_fitted('predict')
# --> 487         return self.best_estimator_.predict(X)
#     488
#     489     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/xgboost/sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features, base_margin)
#     599         if ntree_limit is None:
#     600             ntree_limit = getattr(self, "best_ntree_limit", 0)
# --> 601         return self.get_booster().predict(test_dmatrix,
#     602                                           output_margin=output_margin,
#     603                                           ntree_limit=ntree_limit,
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training)
#    1441
#    1442         if validate_features:
# -> 1443             self._validate_features(data)
#    1444
#    1445         length = c_bst_ulong()
#
# ~/anaconda3/envs/wiita/lib/python3.8/site-packages/xgboost/core.py in _validate_features(self, data)
#    1859                             ', '.join(str(s) for s in my_missing))
#    1860
# -> 1861                 raise ValueError(msg.format(self.feature_names,
#    1862                                             data.feature_names))
#    1863
#
# ValueError: feature_names mismatch: ['NFIC', 'IKZF1', 'YY1', 'ARNT', 'NFYB', 'ATF2', 'SP1', 'FOS', 'CREB1', 'POU2F2', 'TBP', 'MAZ', 'HNF4A', 'NR2F1', 'STAT5A', 'ELF1', 'GATA2', 'MEF2A', 'RELA', 'SPI1', 'NFATC1', 'JUND', 'MYB', 'PAX5', 'EBF1', 'CEBPB', 'JUNB', 'FOXK2', 'MXI1', 'TAF1', 'ZNF687', 'GATA3', 'NR2C1', 'CTBP2', 'ZNF207', 'STAT3', 'SMAD1', 'SIN3A', 'PBX3', 'MTA1', 'EZH2', 'ZEB1', 'RCOR1', 'HNRNPLL', 'SRF', 'BCL3', 'RAD21', 'KLF5', 'MAX', 'MYC', 'BACH1', 'ZNF217', 'ETV6', 'EED', 'BCL11A', 'NBN', 'EP300', 'TCF12', 'MTA2', 'RELB', 'BATF', 'BHLHE40', 'TBX21', 'RUNX3', 'XBP1', 'IRF2', 'STAT1', 'FOXP3', 'TCF4', 'THRB', 'FOXA1', 'PENK', 'ESR1', 'TAF13', 'PGR', 'HNF1A', 'POU2F1', 'NFATC2', 'RXRA', 'AR', 'HOXD10', 'RARB', 'VDR', 'GCFC2', 'ATF1', 'RBPJ', 'NR3C1', 'TP53', 'SRY', 'CEBPA', 'HOXD9', 'ATF3', 'ETV4', 'E2F1', 'ETFA', 'ETFB', 'EGR3', 'WT1', 'AHR', 'RARA', 'NFKB1', 'USF2', 'IRF1', 'LEF1', 'ELK1', 'STAT4', 'GATA1', 'ETS2', 'ETS1'] ['ATF1', 'XBP1', 'GCFC2', 'IRF2', 'NFYB', 'CREB1', 'RBPJ', 'TCF12', 'TP53', 'STAT1', 'TAF1', 'ATF2', 'EED', 'SP1', 'HNRNPLL', 'IKZF1', 'BCL11A', 'POU2F1', 'ARNT', 'NBN']
# expected BATF, PAX5, STAT4, BHLHE40, WT1, EP300, BACH1, POU2F2, EGR3, MYC, KLF5, USF2, NR2C1, GATA3, STAT5A, PBX3, GATA1, CEBPB, NFATC1, AHR, ESR1, ZNF217, THRB, MTA2, ZNF207, MAZ, ATF3, BCL3, SPI1, ETFB, ETV6, TBX21, MTA1, TCF4, RELB, RUNX3, TBP, VDR, ELF1, LEF1, ZEB1, ETS1, EZH2, HOXD9, JUND, ETV4, ZNF687, SMAD1, RCOR1, SRF, EBF1, TAF13, YY1, PGR, NFIC, NR2F1, HNF4A, SIN3A, NFATC2, IRF1, RARB, PENK, FOXP3, MYB, ELK1, RXRA, CEBPA, AR, ETFA, FOXK2, JUNB, MEF2A, MXI1, STAT3, FOXA1, SRY, FOS, HOXD10, RAD21, HNF1A, RARA, E2F1, RELA, GATA2, ETS2, MAX, NFKB1, CTBP2, NR3C1 in input data
